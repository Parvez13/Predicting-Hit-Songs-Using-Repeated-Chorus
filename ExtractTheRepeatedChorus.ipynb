# %% [markdown]
# ### Load dataset
#
# - `paths:` list of paths of full songs.
# - `titles:` list of titles of songs.
# - `data:` list of dictionary that contains chorus.

# %%
import pandas as pd
dataset = pd.read_csv('DataWithMusic2.csv')
paths = list(dataset['Path'])
titles = list(dataset['Title'])
data = []

# %%
paths
# Out:
# ['Songs/The Weeknd - Blinding Lights (Official Video).wav',
#  'Songs/Olivia Rodrigo - good 4 u (Official Video).wav',
#  'Songs/Olivia Rodrigo - drivers license (Official Video).wav',
#  'Songs/Lil Nas X - MONTERO (Call Me By Your Name) (Official Video).wav',
#  'Songs/BTS Butter Official MV.wav',
#  'Songs/Olivia Rodrigo - deja vu (Official Video).wav',
#  'Songs/Ariana Grande - positions (official video).wav',
#  'Songs/Ed Sheeran - Bad Habits (Lyrics).wav',
#  'Songs/Luke Combs - Forever After All (Official Video).wav',
#  'Songs/POP SMOKE - WHAT YOU KNOW BOUT LOVE (Official Video).wav',
#  'Songs/Billie Eilish - Therefore I Am (Official Music Video).wav',
#  'Songs/INNA - Up.wav',
#  'Songs/Olivia Rodrigo - traitor (Lyrics).wav',
#  'Songs/BTS Dynamite Official MV.wav',
#  'Songs/Doja Cat - Need To Know (Lyrics).wav',
#  'Songs/Taylor Swift - willow (Official Music Video).wav',
#  'Songs/Luke Combs - Better Together (Lyrics).wav',
#  'Songs/Doja Cat - Streets (Audio).wav',
#  "Songs/Drake - What's Next (Official Music Video).wav",
#  'Songs/Justin Bieber - Anyone.wav',
#  'Songs/Ariana Grande - pov (audio).wav',
#  'Songs/The Weeknd - Take My Breath (Official Music Video).wav',
#  'Songs/Billie Eilish - Happier Than Ever (Official Music Video).wav',
#  'Songs/Post Malone - Circles.wav',
#  'Songs/Harry Styles - Adore You (Official Video).wav',
#  'Songs/Maroon 5 - Memories (Official Video).wav',
#  'Songs/Doja Cat - Say So (Official Video).wav',
#  'Songs/Billie Eilish - everything i wanted.wav',
#  'Songs/Harry Styles - Watermelon Sugar (Official Video).wav',
#  'Songs/The Weeknd - Heartless (Official Video).wav',
#  'Songs/DaBaby - BOP on Broadway (Hip Hop Musical).wav',
#  'Songs/Drake - Toosie Slide (Official Music Video).wav',
#  "Songs/Morgan Wallen - Chasin' You (Dream Video).wav",
#  'Songs/KRYPTO9095 FT. D3MSTREET WOAH (OFFICIAL SONG TO WOAH DANCE).wav',
#  'Songs/Travis Scott - HIGHEST IN THE ROOM (Official Music Video).wav',
#  'Songs/Billie Eilish - bad guy.wav',
#  'Songs/Justin Bieber - Yummy (Official Video).wav',
#  'Songs/Lil Nas X - Panini (Official Video).wav',
#  'Songs/Lil Baby - Emotionally Scarred.wav',
#  'Songs/Lil Baby - The Bigger Picture (Official Music Video).wav',
#  "Songs/Rag'n'Bone Man - Human (Official Video).wav",
#  'Songs/Lil Baby - Sum 2 Prove (Official Video).wav',
#  'Songs/Halsey - You should be sad.wav',
#  'Songs/POP SMOKE - DIOR (OFFICIAL VIDEO).wav',
#  "Songs/Luke Combs - Even Though I'm Leaving (Official Video).wav",
#  'Songs/Juice WRLD - Wishing Well (Official Music Video).wav',
#  'Songs/Morgan Wallen - More Than My Hometown (Official Music Video).wav',
#  "Songs/Luke Combs - Lovin' On You (Official Video).wav",
#  'Songs/Halsey - Without Me.wav',
#  'Songs/Post Malone - Wow. (Official Music Video).wav',
#  'Songs/Ariana Grande - 7 rings (Official Video).wav',
#  'Songs/Travis Scott - SICKO MODE ft. Drake.wav',
#  'Songs/Jonas Brothers - Sucker (Official Video).wav',
#  'Songs/Ariana Grande - thank u, next (Official Video).wav',
#  'Songs/Dababy - Suge (Yea Yea) Official Music Video.wav',
#  "Songs/Shawn Mendes - If I Can't Have You.wav",
#  'Songs/Post Malone - Better Now.wav',
#  "Songs/Ariana Grande - break up with your girlfriend, i'm bored (Official Video).wav",
#  'Songs/LISA - MONEY (Lyrics).wav',
#  'Songs/Taylor Swift - You Need To Calm Down.wav',
#  'Songs/Luke Combs - Beautiful Crazy.wav',
#  'Songs/Juice WRLD - Lucid Dreams (Directed by Cole Bennett).wav',
#  'Songs/Morgan Wallen - Whiskey Glasses (Official Video).wav',
#  'Songs/Luke Combs - Beer Never Broke My Heart (Official Video).wav',
#  "Songs/Billie Eilish - when the party's over.wav",
#  'Songs/Ariana Grande - breathin.wav',
#  'Songs/Billie Eilish - bury a friend.wav',
#  'Songs/Lil Baby, Gunna - Close Friends.wav',
#  'Songs/P!NK - Walk Me Home (Official Video).wav',
#  'Songs/Juice WRLD - Robbery (Directed by Cole Bennett).wav',
#  "Songs/Drake - God's Plan.wav",
#  'Songs/Ed Sheeran - Perfect (Official Music Video).wav',
#  'Songs/Drake - In My Feelings.wav',
#  'Songs/Drake - Nice For What.wav',
#  'Songs/XXXTENTACION - SAD!.wav',
#  'Songs/Camila Cabello - Never Be the Same.wav',
#  'Songs/Ariana Grande - no tears left to cry (Official Video).wav',
#  'Songs/Imagine Dragons - Thunder.wav',
#  'Songs/Taylor Swift - Delicate.wav',
#  'Songs/Halsey - Bad At Love.wav',
#  'Songs/Imagine Dragons - Whatever It Takes.wav',
#  'Songs/Post Malone – I Fall Apart (Lyrics) 🎵.wav',
#  'Songs/Shawn Mendes - In My Blood.wav',
#  'Songs/Sam Smith - Too Good At Goodbyes (Official Video).wav',
#  'Songs/Drake - Nonstop.wav',
#  'Songs/Cardi B - Bodak Yellow [OFFICIAL MUSIC VIDEO].wav',
#  'Songs/Maroon 5 - Wait (Official Music Video).wav',
#  'Songs/Cardi B - Be Careful [Official Video].wav',
#  'Songs/Ariana Grande - God is a woman (Official Video).wav',
#  'Songs/Imagine Dragons - Natural.wav',
#  'Songs/Ed Sheeran - Shape of You (Official Music Video).wav',
#  'Songs/The Weeknd - Call Out My Name (Official Video).wav',
#  "Songs/Drake - I'm Upset.wav",
#  'Songs/XXXTENTACION - MOONLIGHT (OFFICIAL MUSIC VIDEO).wav',
#  'Songs/XXXTENTACION - changes.wav',
#  'Songs/Luke Combs - One Number Away.wav',
#  'Songs/Imagine Dragons - Believer (Lyrics).wav',
#  'Songs/Bruno Mars - That’s What I Like (Official Music Video).wav',
#  'Songs/Kendrick Lamar - HUMBLE..wav',
#  'Songs/Future - Mask Off (Official Music Video).wav',
#  'Songs/Bruno Mars - 24K Magic (Official Music Video).wav',
#  "Songs/Shawn Mendes - There's Nothing Holdin' Me Back.wav",
#  'Songs/Rihanna - Love On The Brain.wav',
#  'Songs/BTS FAKE LOVE Official MV.wav',
#  'Songs/Taylor Swift - Look What You Made Me Do.wav',
#  'Songs/Ed Sheeran - Castle On The Hill [Official Music Video].wav',
#  'Songs/The Chainsmokers - Paris (Lyric).wav',
#  'Songs/Mercy - Shawn Mendes (Lyrics).wav',
#  'Songs/Halsey - Now Or Never (Audio).wav',
#  'Songs/BTS DNA Official MV.wav',
#  'Songs/Drake - Passionfruit.wav',
#  'Songs/HVME - GOOSEBUMPS (Official Video).wav',
#  'Songs/Kanye West - Hurricane (Audio).wav',
#  'Songs/P!NK - What About Us (Official Video).wav',
#  'Songs/Harry Styles - Sign of the Times (Official Video).wav',
#  'Songs/Water Under the Bridge.wav',
#  'Songs/Miley Cyrus - Malibu (Official Video).wav',
#  'Songs/Shawn Mendes - Treat You Better.wav',
#  'Songs/XXXTENTACION - Look At Me! (Audio).wav',
#  'Songs/Justin Bieber - Love Yourself (Official Music Video).wav',
#  'Songs/Halsey - Sorry.wav',
#  'Songs/twenty one pilots - Stressed Out [OFFICIAL VIDEO].wav',
#  'Songs/Adele - Hello.wav',
#  'Songs/Rihanna - Needed Me.wav',
#  'Songs/twenty one pilots - Ride (Official Video).wav',
#  'Songs/Shawn Mendes - Stitches (Official Video).wav',
#  'Songs/Drake - Hotline Bling.wav',
#  'Songs/Adele - Send My Love (To Your New Lover).wav',
#  'Songs/Justin Bieber - What Do You Mean (Official Music Video).wav',
#  'Songs/The Weeknd - The Hills (Official Video).wav',
#  "Songs/P!nk - Just Like Fire (From'Alice Through The Looking Glass' - Official Video).wav",
#  'Songs/Ariana Grande - Dangerous Woman.wav',
#  'Songs/Drake - Controlla.wav',
#  'Songs/Meghan Trainor - NO.wav',
#  'Songs/Ariana Grande - Into You (Official Video).wav',
#  'Songs/The Weeknd - In The Night (Official Audio).wav',
#  'Songs/Meghan Trainor - Me Too.wav',
#  'Songs/Post Malone - White Iverson.wav',
#  "Songs/The Weeknd - Can't Feel My Face (Official Video).wav",
#  'Songs/Coldplay - Hymn For The Weekend (Official Video).wav',
#  'Songs/Travis Scott - Antidote.wav',
#  'Songs/Taylor Swift - Wildest Dreams.wav',
#  'Songs/Adele - When We Were Young (Live at The Church Studios).wav',
#  'Songs/Chris Brown - Back To Sleep (Official Video).wav',
#  'Songs/Coldplay - Adventure Of A Lifetime (Official Video).wav',
#  'Songs/Future - Wicked (Official Music Video).wav',
#  'Songs/Ed Sheeran - Thinking Out Loud (Official Music Video).wav',
#  'Songs/Fetty Wap  - Trap Queen (Official Video) Prod. By Tony Fadd.wav',
#  'Songs/Maroon 5 - Sugar (Official Music Video).wav',
#  'Songs/Taylor Swift - Blank Space.wav',
#  'Songs/The Weeknd - Earned It (from Fifty Shades Of Grey) (Official Video - Explicit).wav',
#  'Songs/Taylor Swift - Shake It Off.wav',
#  'Songs/Meghan Trainor - Lips Are Movin (Official Music Video).wav',
#  "Songs/Sam Smith - I'm Not The Only One (Official Video).wav",
#  'Songs/Meghan Trainor - All About That Bass.wav',
#  'Songs/Taylor Swift - Style.wav',
#  'Songs/Ed Sheeran - Photograph (Official Music Video).wav',
#  'Songs/Maroon 5 - Animals (Official Music Video).wav',
#  'Songs/Rihanna - Bitch Better Have My Money (Explicit Audio).wav',
#  'Songs/Sam Smith - Stay With Me (Official Video).wav',
#  'Songs/Beyoncé - 7_11.wav',
#  'Songs/One Direction - Drag Me Down (Official Video).wav',
#  'Songs/Ariana Grande - One Last Time (Lyric Video).wav',
#  'Songs/Meghan Trainor - Dear Future Husband (Official Video).wav',
#  'Songs/Sam Smith - Lay Me Down (Official Video).wav',
#  "Songs/Ed Sheeran - Don't [Official Audio].wav",
#  'Songs/One Direction - Night Changes.wav',
#  'Songs/Drake - Back to Back (Lyrics).wav',
#  'Songs/Pharrell Williams - Happy (Video).wav',
#  'Songs/Imagine Dragons - Demons (Official Video).wav',
#  'Songs/One Direction - Story of My Life.wav',
#  'Songs/Maroon 5 - Maps (Lyric Video).wav',
#  'Songs/Nicki Minaj - Anaconda.wav',
#  'Songs/Miley Cyrus - Wrecking Ball (Official Video).wav',
#  'Songs/Justin Timberlake - Not a Bad Thing (Official Audio).wav',
#  'Songs/Katy Perry - Roar (Official).wav',
#  'Songs/Coldplay - A Sky Full Of Stars (Official Video).wav',
#  'Songs/Sing - Shake It Off Scene _ Fandango Family.wav',
#  'Songs/Imagine Dragons - Radioactive.wav',
#  'Songs/Anne-Marie - BIRTHDAY [Official Video].wav',
#  'Songs/Beyoncé - Partition (Explicit Video).wav',
#  'Songs/Drake - 0 to 100 _ The Catch Up (Explicit).wav',
#  'Songs/Justin Timberlake - Mirrors (Official Video).wav',
#  'Songs/Bruno Mars - When I Was Your Man (Official Music Video).wav',
#  'Songs/Bruno Mars - Locked Out Of Heaven (Official Music Video).wav',
#  'Songs/Taylor Swift - I Knew You Were Trouble.wav',
#  "Songs/Miley Cyrus - We Can't Stop (Official Video).wav",
#  'Songs/Rihanna - Diamonds.wav',
#  "Songs/TREASURE - WEB DRAMA '남고괴담' EP.8.wav",
#  'Songs/Drake - Started From The Bottom (Explicit).wav',
#  'Songs/Taylor Swift - Daylight (Official Audio).wav',
#  'Songs/Lady Gaga - Applause (Official Music Video).wav',
#  'Songs/Maroon 5 - One More Night (Official Music Video).wav',
#  "Songs/Imagine Dragons - It's Time.wav",
#  'Songs/Maroon 5 - Love Somebody (Official Music Video).wav',
#  'Songs/P!nk - Try (Official Video).wav',
#  'Songs/Kesha - Die Young (Lyrics).wav',
#  'Songs/Eminem - Berzerk (Official Music Video) (Explicit).wav',
#  'Songs/Rihanna - Pour It Up (Explicit).wav',
#  'Songs/Taylor Swift - 22.wav',
#  'Songs/One Direction - Best Song Ever.wav',
#  'Songs/Ed Sheeran - The A Team [Official Music Video].wav',
#  'Songs/Kendrick Lamar - Swimming Pools (Drank).wav',
#  'Songs/Ne-Yo - Let Me Love You (Until You Learn To Love Yourself) (Official Music Video).wav',
#  'Songs/Nicki Minaj - Starships (Explicit).wav',
#  'Songs/One Direction - What Makes You Beautiful (Official Video).wav',
#  'Songs/Adele - Set Fire To The Rain (Live at The Royal Albert Hall).wav',
#  'Songs/LMFAO - Sexy and I Know It (Official Video).wav',
#  'Songs/Katy Perry - Wide Awake (Official Video).wav',
#  'Songs/Rihanna - Where Have You Been.wav',
#  'Songs/Bruno Mars - It Will Rain (Official Music Video).wav',
#  'Songs/Justin Bieber - Boyfriend (Official Music Video).wav',
#  'Songs/Katy Perry - Part Of Me (Official).wav',
#  'Songs/Taylor Swift - We Are Never Ever Getting Back Together.wav',
#  'Songs/P!NK - Blow Me (One Last Kiss).wav',
#  'Songs/Katy Perry - The One That Got Away (Official Music Video).wav',
#  'Songs/Adele - Someone Like You (Official Music Video).wav',
#  'Songs/Scream _ Official Trailer (2022 Movie).wav',
#  "Songs/Chris Brown - Don't Wake Me Up (Official Music Video).wav",
#  'Songs/Rumour Has It.wav',
#  'Songs/Beth and Rio - The History of Hotness - Good Girls.wav',
#  'Songs/Coldplay - Paradise (Official Video).wav',
#  'Songs/Carrie Underwood - Blown Away (Official Video).wav',
#  'Songs/Adele - Rolling in the Deep (Official Music Video).wav',
#  'Songs/Young Thug - Climax (ft. 6LACK) [Official Audio].wav',
#  'Songs/Nicki Minaj - Pound The Alarm (Explicit).wav',
#  'Songs/Chris Brown - Turn Up the Music.wav',
#  'Songs/Rihanna - You Da One.wav',
#  'Songs/Katy Perry - Firework (Official Music Video).wav',
#  'Songs/Bruno Mars - Grenade (Official Music Video).wav',
#  'Songs/Nicki Minaj - Super Bass.wav',
#  'Songs/Rihanna - S&M (Official Music Video).wav',
#  'Songs/Katy Perry - Last Friday Night (T.G.I.F.) (Official Music Video).wav',
#  'Songs/Bruno Mars - Just The Way You Are (Official Music Video).wav',
#  'Songs/P!nk - Raise Your Glass (Official Video).wav',
#  'Songs/Lady Gaga - Born This Way (Official Music Video).wav',
#  "Songs/P!nk - F_kin' Perfect (Lyric Video).wav",
#  'Songs/Lil Wayne - How To Love (Official Music Video).wav',
#  'Songs/Bruno Mars - The Lazy Song (Official Music Video).wav',
#  'Songs/Britney Spears - Till The World Ends (Official Video).wav',
#  'Songs/Lady Gaga - The Edge Of Glory (Official Music Video).wav',
#  'Songs/Ke$ha - We R Who We R (Official Video).wav',
#  'Songs/Kesha - Blow (Lyrics).wav',
#  'Songs/Rihanna - Only Girl (In The World) (Official Music Video).wav',
#  'Songs/Britney Spears - I Wanna Go (Official Video).wav',
#  'Songs/Chris Brown - Yeah 3x.wav',
#  'Songs/Kanye West - All Of The Lights ft. Rihanna, Kid Cudi.wav',
#  'Songs/Britney Spears - Hold It Against Me (Official Video).wav',
#  'Songs/K_DA - MORE ft. Madison Beer, (G)I-DLE, Lexie Liu, Jaira Burns, Seraphine (Official Music Video).wav',
#  'Songs/Avril Lavigne - What The Hell(MP3_320K).wav',
#  'Songs/Katy Perry - You and I (Song TikTok) (Harleys In Hawaii) (Lyrics).wav',
#  'Songs/Taylor Swift - Back To December.wav',
#  'Songs/Katy Perry - Teenage Dream (Official Music Video).wav',
#  'Songs/Rihanna - Cheers (Drink To That).wav',
#  'Songs/Drake - Headlines (Explicit).wav',
#  'Songs/Beyoncé - Best Thing I Never Had (Video).wav',
#  "Songs/Chris Brown - She Ain't You (Official Music Video).wav",
#  'Songs/Ke$ha - TiK ToK (Official HD Video).wav',
#  'Songs/Lady Gaga - Bad Romance (Official Music Video).wav',
#  'Songs/Rihanna - Rude Boy (Official Music Video).wav',
#  'Songs/Eminem - Not Afraid (Official Video).wav',
#  'Songs/Ke$ha - Your Love Is My Drug (Official Video).wav',
#  'Songs/Drake - Find Your Love (Official Music Video).wav',
#  'Songs/Lady Gaga - Alejandro.wav',
#  'Songs/Bazzi - Mine (Lyrics).wav',
#  'Songs/Taylor Swift - You Belong With Me.wav',
#  'Songs/Kesha - Take It Off (Lyrics) [Stephen Marcus Bootleg].wav',
#  'Songs/Playboi Carti - Over (Official Audio).wav',
#  'Songs/Maroon 5 - Misery (Official Music Video).wav',
#  'Songs/Kim Dracula - Paparazzi (Lyrics).wav',
#  'Songs/ATB x Topic x A7S - Your Love (9PM).wav',
#  'Songs/Miley Cyrus - Party In The U.S.A. (Official Video).wav',
#  'Songs/Britney Spears - 3 (Official HD Video).wav',
#  "Songs/Alicia Keys - Un-thinkable (I'm Ready) (Official Video).wav",
#  'Songs/Usher - There Goes My Baby (Official Music Video).wav',
#  "Songs/Taylor Swift - Today Was A Fairytale (Taylor's Version) (Lyric Video).wav",
#  'Songs/Eurythmics, Annie Lennox, Dave Stewart - Sweet Dreams (Are Made Of This) (Official Video).wav',
#  'Songs/Carrie Underwood - Undo It (Official Video).wav',
#  'Songs/Daughtry - Life After You.wav',
#  'Songs/Alicia Keys - Try Sleeping with a Broken Heart (Official Video).wav',
#  'Songs/Lady Gaga - Poker Face (Official Music Video).wav',
#  'Songs/Taylor Swift - Love Story.wav',
#  'Songs/Beyoncé - Single Ladies (Put a Ring on It) (Video Version).wav',
#  'Songs/The Fray - You Found Me (Official VIdeo).wav',
#  'Songs/Miley Cyrus - The Climb.wav',
#  'Songs/Best I Ever Had.wav',
#  'Songs/Beyoncé - Halo.wav',
#  'Songs/Katy Perry - Hot N Cold (Official).wav',
#  'Songs/Circus - Britney Spears (Lyrics) 🎵.wav',
#  'Songs/Lady Gaga - LoveGame (Official Music Video).wav',
#  'Songs/Katy Perry - Waking Up In Vegas (Official).wav',
#  'Songs/Demi Lovato - Sober (Lyrics).wav',
#  "Songs/Britney Spears - Womanizer (Director's Cut) (Official HD Video).wav",
#  'Songs/T.I. - Whatever You Like [Official Video].wav',
#  'Songs/Ne-Yo - Mad (Official Music Video).wav',
#  'Songs/Kanye West - Love Lockdown.wav',
#  'Songs/P!nk - So What (Official Video).wav',
#  'Songs/Beyoncé - If I Were A Boy.wav',
#  'Songs/Nickelback - Gotta Be Somebody [OFFICIAL VIDEO].wav',
#  "Songs/P!nk - Please Don't Leave Me (Official Video).wav",
#  'Songs/Coldplay - Viva La Vida (Official Video).wav',
#  'Songs/Akon - Right Now (Na Na Na) (Official Video).wav',
#  'Songs/Ne-Yo - Miss Independent (Official Music Video).wav',
#  'Songs/Daughtry - No Surprise.wav',
#  'Songs/Nickelback - If Today Was Your Last Day [OFFICIAL VIDEO].wav',
#  'Songs/Britney Spears - If U Seek Amy (Official HD Video).wav',
#  'Songs/Taylor Swift - White Horse.wav',
#  'Songs/Rihanna - Disturbia.wav',
#  'Songs/Beyoncé - Diva.wav',
#  'Songs/Justin Bieber - One Time (Official Music Video).wav',
#  'Songs/Never Say Never - The Fray _ Lyrics.wav',
#  'Songs/Leona Lewis - Bleeding Love (US Version - Official Video).wav',
#  'Songs/Alicia Keys - No One (Official Music Video).wav',
#  'Songs/Chris Brown - With You (Official Video).wav',
#  'Songs/Chris Brown - Forever (Official HD Video).wav',
#  'Songs/Rihanna - Take A Bow (Official Music Video).wav',
#  'Songs/Katy Perry - I Kissed A Girl (Official).wav',
#  "Songs/Don't Stop The Music - Rihanna (Lyrics) 🎵.wav",
#  'Songs/Ne-Yo - Closer (Official Music Video).wav',
#  'Songs/Fergie - Clumsy (Official Music Video).wav',
#  'Songs/See You Again.wav',
#  'Songs/Taylor Swift - Our Song.wav',
#  'Songs/A Milli.wav',
#  "Songs/Alicia Keys - Like You'll Never See Me Again (Official Video).wav",
#  'Songs/Taylor Swift - Teardrops On My Guitar.wav',
#  'Songs/Leona Lewis - Better in Time (Official Video).wav',
#  "Songs/Jonas Brothers - Burnin' Up (Official Music Video).wav",
#  "Songs/Fergie - Big Girls Don't Cry (Personal) (Official Music Video).wav",
#  'Songs/Mary J. Blige - Just Fine (Official Music Video).wav',
#  'Songs/Britney Spears - Piece Of Me.wav',
#  'Songs/Miley Cyrus - 7 Things (Official Video).wav',
#  'Songs/Daughtry - Feels Like Tonight (Official Music Video).wav',
#  'Songs/Beyoncé - Irreplaceable.wav',
#  'Songs/Carrie Underwood - Before He Cheats (Official Video).wav',
#  "Songs/Akon - Don't Matter (Official Music Video).wav",
#  'Songs/Avril Lavigne - Girlfriend.wav',
#  'Songs/Maroon 5 - Makes Me Wonder (Official Music Video).wav',
#  "Songs/Daughtry - It's Not Over (Official Music Video).wav",
#  'Songs/Fergie - Fergalicious (Official Music Video).wav',
#  'Songs/What Goes Around...Comes Around (Official Video).wav',
#  'Songs/The Fray - How to Save a Life (Official Video).wav',
#  'Songs/Daughtry - Home (Official Video).wav',
#  'Songs/Kanye West - Stronger.wav',
#  'Songs/P!NK - U + Ur Hand.wav',
#  'Songs/Nickelback - Rockstar [OFFICIAL VIDEO].wav',
#  'Songs/Summer Love.wav',
#  'Songs/Nickelback - If Everyone Cared [OFFICIAL VIDEO].wav',
#  'Songs/Ne-Yo - Because Of You (Official Music Video).wav',
#  'Songs/Justin Timberlake - SexyBack (Official Video) ft. Timbaland.wav',
#  'Songs/Keep Holding On - Avril Lavigne (lyrics).wav',
#  'Songs/P!nk - Who Knew (Official Video).wav',
#  "Songs/T.I. - Big Things Poppin' (Do It) [Official Video].wav",
#  'Songs/Gwen Stefani - Wind It Up.wav',
#  'Songs/Rihanna - Shut Up And Drive.wav',
#  'Songs/Nickelback - Far Away [OFFICIAL VIDEO].wav',
#  'Songs/Justin Timberlake - LoveStoned _ I Think She Knows Interlude (Official Video).wav',
#  'Songs/Sean Paul - Temperature (Official Video).wav',
#  'Songs/Mary J. Blige - Be Without You (Official Music Video).wav',
#  'Songs/The Fray - Over My Head (Cable Car) (Video).wav',
#  'Songs/Chris Brown - Run It! (Official HD Video) ft. Juelz Santana.wav',
#  'Songs/Ne-Yo - So Sick (Official Music Video).wav',
#  'Songs/Rihanna - SOS (Official Music Video).wav',
#  'Songs/Fergie - London Bridge (Oh Snap) (Official Music Video).wav',
#  'Songs/Rascal Flatts - What Hurts The Most (Official Video).wav',
#  'Songs/Rihanna - Unfaithful (Official Music Video).wav',
#  'Songs/Chris Brown - Yo (Excuse Me Miss) (Official Video).wav',
#  'Songs/What You Know.wav',
#  "Songs/Nickelback - Savin' Me.wav",
#  'Songs/Ne-Yo - Sexy Love (Official Music Video).wav',
#  'Songs/Rascal Flatts - Life Is a Highway (From Cars_Official Video).wav',
#  'Songs/Carrie Underwood - Jesus, Take The Wheel (Official Video).wav',
#  "Songs/Sean Paul - We Be Burnin' (Recognize It) [Official Video].wav",
#  'Songs/Chris Brown - Say Goodbye (Official HD Video).wav',
#  "Songs/Eminem - When I'm Gone (Official Music Video).wav",
#  "Songs/Ne-Yo - When You're Mad (Official Music Video).wav",
#  'Songs/T.I. - Why You Wanna [Official Video].wav',
#  'Songs/P!nk - Stupid Girls.wav',
#  'Unpopular/Adele - Easy On Me (Official Lyric Video).wav',
#  "Unpopular/Taylor Swift - All Too Well (Taylor's Version) (Lyric Video).wav",
#  'Unpopular/Adele - Oh My God (Official Lyric Video).wav',
#  'Unpopular/Ed Sheeran - Shivers [Official Video].wav',
#  'Unpopular/Adele - I Drink Wine (Official Lyric Video).wav',
#  'Unpopular/Adele - My Little Love (Official Lyric Video).wav',
#  'Unpopular/Adele - Can I Get It (Official Lyric Video).wav',
#  'Unpopular/Adele - To Be Loved (Official Lyric Video).wav',
#  'Unpopular/Justin Bieber - Ghost.wav',
#  'Unpopular/Adele - Strangers By Nature (Official Lyric Video).wav',
#  'Unpopular/Lil Nas X - THATS WHAT I WANT (Official Video).wav',
#  'Unpopular/Adele - Cry Your Heart Out (Official Lyric Video).wav',
#  'Unpopular/Luke Combs - Cold As You (Official Video).wav',
#  'Unpopular/Adele - Hold On (Official Lyric Video).wav',
#  'Unpopular/Adele - Woman Like Me (Official Lyric Video).wav',
#  'Unpopular/Adele - Love Is A Game (Official Lyric Video).wav',
#  'Unpopular/Juice WRLD - Already Dead (Official Music Video).wav',
#  'Unpopular/Morgan Wallen - Sand In My Boots (The Dangerous Sessions).wav',
#  "Unpopular/Taylor Swift - Message In A Bottle (Taylor's Version) (From The Vault) (Lyric Video).wav",
#  'Unpopular/Doja Cat - Woman (Official Video).wav',
#  "Unpopular/Luke Combs - Doin' This (Official Video).wav",
#  "Unpopular/Taylor Swift - Red (Taylor's Version) (Lyric Video).wav",
#  "Unpopular/Taylor Swift - State Of Grace (Taylor's Version) (Lyric Video).wav",
#  'Unpopular/Travis Scott - ESCAPE PLAN (Official Music Video).wav',
#  "Unpopular/Jonas Brothers - Who's In Your Head (Official Video).wav",
#  'Unpopular/BTS Permission to Dance Official MV.wav',
#  'Unpopular/Post Malone - Motley Crew (Official Video).wav',
#  "Unpopular/Doja Cat - Ain't Shit (Visualizer).wav",
#  "Unpopular/Camila Cabello - Don't Go Yet (Official Video - Extended Version).wav",
#  'Unpopular/DaBaby - BALL IF I WANT TO (Official Video).wav',
#  'Unpopular/Olivia Rodrigo - favorite crime (Lyric Video).wav',
#  'Unpopular/Olivia Rodrigo - happier (Lyric Video).wav',
#  'Unpopular/DaBaby - Red Light Green Light (Official Video).wav',
#  'Unpopular/Billie Eilish - NDA (Official Music Video).wav',
#  'Unpopular/Olivia Rodrigo - brutal (Official Video).wav',
#  'Unpopular/Justin Bieber - Off My Face (Live from Paris).wav',
#  'Unpopular/Justin Bieber - 2 Much (Live from Paris).wav',
#  'Unpopular/DaBaby - Masterpiece (Official Video).wav',
#  'Unpopular/Justin Bieber - Deserve You (Visualizer).wav',
#  'Unpopular/Morgan Wallen - Wasted On You (The Dangerous Sessions).wav',
#  'Unpopular/Justin Bieber - Somebody (Live from Paris).wav',
#  'Unpopular/Ariana Grande - Santa Tell Me (Official Video).wav',
#  'Unpopular/Lil Nas X - HOLIDAY (Official Video).wav',
#  'Unpopular/Ed Sheeran - Afterglow [Official Performance Video].wav',
#  'Unpopular/Eminem - GNAT (Directed by Cole Bennett).wav',
#  "Unpopular/Justin Bieber - Rockin' Around The Christmas Tree (Audio).wav",
#  'Unpopular/Carrie Underwood - Favorite Time Of Year (Official Audio Video).wav',
#  'Unpopular/Taylor Swift - champagne problems (Official Lyric Video).wav',
#  'Unpopular/Morgan Wallen - 7 Summers.wav',
#  'Unpopular/Taylor Swift - ‘tis the damn season (Official Lyric Video).wav',
#  'Unpopular/Carrie Underwood - Silent Night (Audio).wav',
#  'Unpopular/Harry Styles - Golden (Official Video).wav',
#  'Unpopular/BTS Life Goes On Official MV.wav',
#  'Unpopular/Blue & Grey.wav',
#  'Unpopular/Stay.wav',
#  'Unpopular/Morgan Wallen - Somebody’s Problem (Official Lyric Video).wav',
#  'Unpopular/Morgan Wallen - Still Goin Down (Official Lyric Video).wav',
#  'Unpopular/Shawn Mendes - Wonder.wav',
#  'Unpopular/내 방을 여행하는 법.wav',
#  'Unpopular/BTS Telepathy MTV Unplugged.wav',
#  'Unpopular/BTS Dis-ease Lyrics [Color Coded Lyrics_Han_Rom_Eng].wav',
#  'Unpopular/Miley Cyrus - Midnight Sky (Official Video).wav',
#  'Unpopular/Morgan Wallen - Livin’ The Dream (Official Lyric Video).wav',
#  'Unpopular/Morgan Wallen - Cover Me Up.wav',
#  'Unpopular/Juice WRLD - Conversations (Official Audio).wav',
#  'Unpopular/Juice WRLD - Blood On My Jeans (Official Audio).wav',
#  'Unpopular/Juice WRLD - Righteous (Official Video).wav',
#  'Unpopular/POP SMOKE - GOT IT ON ME (OFFICIAL VIDEO).wav',
#  'Unpopular/Juice WRLD - Titanic (Official Audio).wav',
#  'Unpopular/Juice WRLD - Stay High (Official Audio).wav',
#  'Unpopular/Juice WRLD - Bad Energy (Official Audio).wav',
#  'Unpopular/Pop Smoke - Something Special (Audio).wav',
#  'Unpopular/Juice WRLD - Up Up And Away (Official Audio).wav',
#  'Unpopular/Juice WRLD - Fighting Demons (Official Audio).wav',
#  'Unpopular/Juice WRLD - Man Of The Year (Official Audio).wav',
#  "Unpopular/Juice WRLD - Can't Die (Official Audio).wav",
#  'Unpopular/Juice WRLD - Screw Juice (Official Audio).wav',
#  'Unpopular/The Weeknd - In Your Eyes (Official Audio).wav',
#  'Unpopular/The Weeknd - Alone Again (Official Audio).wav',
#  'Unpopular/The Weeknd - After Hours (Audio).wav',
#  'Unpopular/The Weeknd - Scared To Live (Audio).wav',
#  'Unpopular/The Weeknd - Hardest To Love (Audio).wav',
#  'Unpopular/Lady Gaga - Stupid Love (Official Music Video).wav',
#  'Unpopular/The Weeknd - Too Late.wav',
#  'Unpopular/The Weeknd - Snowchild (Animated Video).wav',
#  'Unpopular/The Weeknd - Escape From LA (Audio).wav',
#  'Unpopular/The Weeknd - Faith (Audio).wav',
#  'Unpopular/The Weeknd - Repeat After Me (Interlude) (Audio).wav',
#  'Unpopular/Jonas Brothers - What A Man Gotta Do (Official Video).wav',
#  'Unpopular/The Weeknd - Until I Bleed Out (Official Video).wav',
#  'Unpopular/Sam Smith - To Die For.wav',
#  "Unpopular/Jonas Brothers - Like It's Christmas (Official Lyric Video).wav",
#  'Unpopular/Taylor Swift - Lover.wav',
#  'Unpopular/Halsey - Graveyard.wav',
#  'Unpopular/DaBaby - VIBEZ (Official Music Video).wav',
#  "Unpopular/Juice WRLD 'Let Me Know (I Wonder Why Freestyle)' (Official Audio).wav",
#  'Unpopular/Doja Cat - Candy (Lyrics).wav',
#  'Unpopular/Billie Eilish - all the good girls go to hell.wav',
#  'Unpopular/Kanye West - Follow God.wav',
#  'Unpopular/Katy Perry - Never Really Over (Official Video).wav',
#  'Unpopular/Cardi B - Press [Official Music Video].wav',
#  'Unpopular/Taylor Swift - The Archer (Lyric Video).wav',
#  'Unpopular/Halsey - Nightmare (Lyrics).wav',
#  'Unpopular/Jonas Brothers - Cool (Official Video).wav',
#  'Unpopular/Beyoncé - Before I Let Go (Official Audio).wav',
#  'Unpopular/Carrie Underwood - Southbound (Official Music Video).wav',
#  'Unpopular/Nicki Minaj - MEGATRON.wav',
#  'Unpopular/Imagine Dragons - Bad Liar.wav',
#  'Unpopular/Lil Baby - Pure Cocaine (Audio).wav',
#  'Unpopular/Billie Eilish - wish you were gay (Audio).wav',
#  'Unpopular/Juice WRLD - Hear Me Calling.wav',
#  'Unpopular/Chris Brown - Undecided (Official Video).wav',
#  'Unpopular/Juice WRLD - Empty (Official Audio).wav',
#  'Unpopular/Carrie Underwood - Love Wins (Official Video).wav',
#  'Unpopular/Katy Perry - Cozy Little Christmas.wav',
#  'Unpopular/Luke Combs - She Got the Best of Me.wav',
#  'Unpopular/Lil Wayne - Uproar ft. Swizz Beatz (Official Music Video) ft. Swizz Beatz.wav',
#  'Unpopular/XXXTENTACION - BAD! (Official Music Video).wav',
#  'Unpopular/Ariana Grande - imagine (Audio).wav',
#  'Unpopular/Camila Cabello - Consequences (orchestra).wav',
#  'Unpopular/Juice WRLD - Armed & Dangerous (Directed by Cole Bennett).wav',
#  'Unpopular/Billie Eilish - Ocean Eyes (Official Music Video).wav',
#  'Unpopular/Mob Ties.wav',
#  'Unpopular/Juice WRLD - All Girls Are The Same (Directed by Cole Bennett).wav',
#  'Unpopular/Carrie Underwood - Cry Pretty (Official Video).wav',
#  'Unpopular/twenty one pilots - Jumpsuit (Official Video).wav',
#  'Unpopular/Kanye West - All Mine (Lyric Video).wav',
#  'Unpopular/Billie Eilish - you should see me in a crown (Vertical Video).wav',
#  'Unpopular/Emotionless.wav',
#  'Unpopular/Can’t Take A Joke.wav',
#  'Unpopular/Meghan Trainor - No Excuses.wav',
#  'Unpopular/P!NK - Beautiful Trauma (Official Video).wav',
#  'Unpopular/Chris Brown - Tempo (Official Video).wav',
#  'Unpopular/the remedy for a broken heart (why am I so in love).wav',
#  'Unpopular/Post Malone - Candy Paint (The Fate of the Furious - The Album)\xa0[Official Audio].wav',
#  'Unpopular/Taylor Swift - …Ready For It.wav',
#  "Unpopular/Lil Baby 'My Dawg' (WSHH Exclusive - Official Music Video).wav",
#  'Unpopular/Eminem - Believe.wav',
#  'Unpopular/Luke Combs - When It Rains It Pours.wav',
#  'Unpopular/Taylor Swift - Call It What You Want (Lyric Video).wav',
#  'Unpopular/XXXTENTACION - Jocelyn Flores (Audio).wav',
#  'Unpopular/Taylor Swift - Gorgeous (Lyric Video).wav',
#  'Unpopular/Chris Brown - Questions (Official Video).wav',
#  'Unpopular/Post Malone - Go Flex.wav',
#  'Unpopular/Bruno Mars - Versace on the Floor (Official Music Video).wav',
#  'Unpopular/Travis Scott - BUTTERFLY EFFECT.wav',
#  'Unpopular/Rascal Flatts - Yours If You Want It (Official Video).wav',
#  'Unpopular/Camila Cabello - Crying In The Club (Official Video).wav',
#  'Unpopular/Chris Brown - Privacy (Official Video).wav',
#  'Unpopular/Lady Gaga - The Cure (Official Audio).wav',
#  'Unpopular/Drake - Signs.wav',
#  'Unpopular/The Weeknd - Reminder (Official Video).wav',
#  'Unpopular/Kendrick Lamar - ELEMENT..wav',
#  'Unpopular/Lady Gaga - Million Reasons (Official Music Video).wav',
#  'Unpopular/Nicki Minaj - Regret In Your Tears.wav',
#  'Unpopular/Ed Sheeran - Galway Girl [Official Music Video].wav',
#  'Unpopular/Future - Draco.wav',
#  'Unpopular/The Weeknd - Party Monster (Official Video).wav',
#  'Unpopular/Ed Sheeran - Dive [Official Audio].wav',
#  'Unpopular/Carrie Underwood - Dirty Laundry (Official Video).wav',
#  'Unpopular/Six Feet Under.wav',
#  'Unpopular/Kanye West - Fade (Explicit).wav',
#  'Unpopular/Sex With Me.wav',
#  'Unpopular/Katy Perry - Rise (Official).wav',
#  'Unpopular/Carrie Underwood - Church Bells (Official Video).wav',
#  'Unpopular/Fetty Wap - Wake Up [Official Video].wav',
#  'Unpopular/Famous.wav',
#  'Unpopular/Fergie - M.I.L.F. $ (Official Music Video).wav',
#  'Unpopular/Drake - Childs Play.wav',
#  'Unpopular/Drake - Summer Sixteen (Audio).wav',
#  'Unpopular/Carrie Underwood - Heartbeat (Official Video).wav',
#  'Unpopular/Rascal Flatts - I Like The Sound Of That (Official Video).wav',
#  'Unpopular/Taylor Swift - New Romantics.wav',
#  'Unpopular/The Weeknd - Acquainted (Official Audio).wav',
#  'Unpopular/Justin Bieber - Company (Official Music Video).wav',
#  'Unpopular/Fetty Wap - Jimmy Choo [Audio Only].wav',
#  'Unpopular/Gwen Stefani - Make Me Like You (Audio).wav',
#  'Unpopular/Ariana Grande - Focus.wav',
#  'Unpopular/Fetty Wap  - Again [Audio Only].wav',
#  "Unpopular/Justin Bieber - I'll Show You (Official Music Video).wav",
#  'Unpopular/Gwen Stefani - Used To Love You.wav',
#  'Unpopular/Halsey - New Americana.wav',
#  'Unpopular/Drake - Right Hand.wav',
#  'Unpopular/Carrie Underwood - Smoke Break (Official Video).wav',
#  'Unpopular/Justin Bieber - Purpose (PURPOSE  - The Movement) (Official Music Video).wav',
#  'Unpopular/Justin Bieber - Mark My Words (PURPOSE  - The Movement).wav',
#  'Unpopular/Justin Bieber - Life is worth living (Lyrics).wav',
#  'Unpopular/Justin Bieber - Children (Lyrics).wav',
#  'Unpopular/Chris Brown - Liquor.wav',
#  'Unpopular/Been You.wav',
#  'Unpopular/One Direction - If I Could Fly (Audio).wav',
#  'Unpopular/Olivia - One Direction (Lyrics).wav',
#  'Unpopular/Get Used To It.wav',
#  'Unpopular/A.M. - One Direction (Lyrics).wav',
#  'Unpopular/Fetty Wap - RGF Island [Audio Only].wav',
#  'Unpopular/One Direction - Temporary Fix (Audio).wav',
#  'Unpopular/Trust.wav',
#  'Unpopular/One Direction - Never Enough (Audio).wav',
#  "Unpopular/Maroon 5 - This Summer's Gonna Hurt Like A Motherf_r (Explicit) (Official Music Video).wav",
#  'Unpopular/Nicki Minaj - The Night Is Still Young.wav',
#  'Unpopular/Future - F_ck Up Some Commas (Official Music Video).wav',
#  'Unpopular/Carrie Underwood - Little Toy Guns (Official Video).wav',
#  'Unpopular/Kendrick Lamar - Alright.wav',
#  'Unpopular/twenty one pilots - Tear In My Heart [OFFICIAL VIDEO].wav',
#  'Unpopular/Drake - Energy.wav',
#  'Unpopular/Imagine Dragons - I Bet My Life.wav',
#  'Unpopular/Know Yourself.wav',
#  'Unpopular/Kendrick Lamar - King Kunta.wav',
#  'Unpopular/Legend.wav',
#  'Unpopular/The Blacker The Berry.wav',
#  'Unpopular/10 Bands.wav',
#  'Unpopular/twenty one pilots - Fairly Local [OFFICIAL VIDEO].wav',
#  'Unpopular/Carrie Underwood - Something in the Water (Official Video).wav',
#  'Unpopular/Fergie - L.A.LOVE (la la) ft. YG (Official Music Video).wav',
#  'Unpopular/One Direction - Steal My Girl.wav',
#  'Unpopular/The Weeknd - Often (NSFW) (Official Video).wav',
#  'Unpopular/Kendrick Lamar - i (Official Video).wav',
#  "Unpopular/Gwen Stefani - Baby Don't Lie.wav",
#  'Unpopular/Katy Perry - This Is How We Do (Official).wav',
#  'Unpopular/One Direction - Stockholm Syndrome (Audio).wav',
#  'Unpopular/Nicki Minaj - Pills N Potions (Official).wav',
#  'Unpopular/Pharrell Williams - Come Get It Bae (Video).wav',
#  'Unpopular/Usher - Good Kisser (Official Video).wav',
#  'Unpopular/#SELFIE (Official Music Video) - The Chainsmokers.wav',
#  'Unpopular/Bruno Mars - Young Girls (Official Audio).wav',
#  'Unpopular/Rascal Flatts - Rewind (Official Video).wav',
#  'Unpopular/Coldplay - Magic (Official Video).wav',
#  'Unpopular/Imagine Dragons - On Top Of The World (Official Music Video).wav',
#  'Unpopular/Katy Perry - Unconditionally (Official).wav',
#  'Unpopular/Eminem - Rap God (Explicit).wav',
#  'Unpopular/Beyoncé - XO (Video).wav',
#  'Unpopular/Drake - The Language (Explicit).wav',
#  'Unpopular/Justin Timberlake - TKO (Official Video).wav',
#  'Unpopular/Justin Bieber - All That Matters (Official Audio).wav',
#  'Unpopular/Kanye West - Bound 2 (Explicit).wav',
#  'Unpopular/Future - Honest.wav',
#  'Unpopular/Britney Spears - Perfume (Official Video).wav',
#  'Unpopular/Drake - Worst Behavior.wav',
#  'Unpopular/Daughtry - Waiting for Superman (Official Video).wav',
#  'Unpopular/Eminem - Survival (Explicit).wav',
#  'Unpopular/One Direction - Diana (Audio).wav',
#  'Unpopular/One Direction - Midnight Memories.wav',
#  'Unpopular/Rihanna - What Now (Official).wav',
#  "Unpopular/Taylor Swift - Red (Taylor's Version) (Lyric Video).wav",
#  'Unpopular/Bruno Mars - Gorilla (Official Music Video).wav',
#  'Unpopular/One Direction - Strong (Audio).wav',
#  'Unpopular/Britney Spears - Work B_ch (Official Music Video).wav',
#  'Unpopular/Ariana Grande - Last Christmas (Lyrics) _ Last Christmas I gave you my heart.wav',
#  'Unpopular/Justin Timberlake - Take Back the Night (Official Video).wav',
#  'Unpopular/Britney Spears - Ooh La La (From The Smurfs 2).wav',
#  "Unpopular/Avril Lavigne - Here's to Never Growing Up.wav",
#  'Unpopular/Chris Brown - Fine China (Official Video).wav',
#  'Unpopular/Carrie Underwood - Two Black Cadillacs (Official Video).wav',
#  'Unpopular/One Direction - Kiss You (Official).wav',
#  'Unpopular/Justin Timberlake - Pusher Love Girl.wav',
#  'Unpopular/Future - Neva End (Remix) (Official Music Video) ft. Kelly Rowland.wav',
#  "Unpopular/Ke$ha - C'Mon (Official Lyric Video).wav",
#  'Unpopular/One Direction - One Way Or Another (Teenage Kicks).wav',
#  "Unpopular/Kendrick Lamar - Bitch, Don't Kill My Vibe (Explicit).wav",
#  'Unpopular/Rascal Flatts - Changed (Official Video).wav',
#  'Unpopular/Nicki Minaj - Va Va Voom (Explicit).wav',
#  'Unpopular/One Direction - Little Things.wav',
#  'Unpopular/The Weeknd - Wicked Games (Official Video - Explicit).wav',
#  "Unpopular/Chris Brown - Don't Judge Me.wav",
#  'Unpopular/Adele - Skyfall (Lyric Video).wav',
#  "Unpopular/One Direction - Live While We're Young.wav",
#  'Unpopular/Taylor Swift - Begin Again.wav',
#  'Unpopular/Future - Turn On The Lights (Official Music Video).wav',
#  'Unpopular/Rascal Flatts - Come Wake Me Up (Official Music Video).wav',
#  'Unpopular/Beyoncé - Dance for You (Video).wav',
#  'Unpopular/One Direction - One Thing.wav',
#  'Unpopular/T.I. - Go Get It [Official Video].wav',
#  'Unpopular/Taylor Swift - Eyes Open (Lyric Version).wav',
#  'Unpopular/Taylor Swift - Ours.wav',
#  'Unpopular/Beyoncé - Love On Top (Official Video).wav',
#  'Unpopular/Rascal Flatts - Banjo (Official Music Video).wav',
#  'Unpopular/LMFAO - Sorry For Party Rocking.wav',
#  'Unpopular/Justin Bieber - Mistletoe (Official Music Video).wav',
#  'Unpopular/Lady Gaga - Marry The Night (Official Music Video).wav',
#  'Unpopular/Nickelback - When We Stand Together.wav',
#  'Unpopular/Avril Lavigne - Wish You Were Here (Video).wav',
#  'Unpopular/Lil Wayne - Blunt Blowin (Visualizer).wav',
#  'Unpopular/Beyoncé - Countdown (Official Video).wav',
#  'Unpopular/Nicki Minaj - Stupid Hoe (Explicit).wav',
#  'Unpopular/Taylor Swift - If This Was a Movie (Lyrics).wav',
#  'Unpopular/Taylor Swift - Sparks Fly.wav',
#  'Unpopular/Hate Sleeping Alone - Drake _ Lyrics On Screen [HD].wav',
#  'Unpopular/Britney Spears - Criminal (Official Video).wav',
#  'Unpopular/Shot For Me.wav',
#  'Unpopular/Rihanna - California King Bed.wav',
#  'Unpopular/Coldplay - Every Teardrop Is a Waterfall (Official Video).wav',
#  'Unpopular/Taylor Swift - Mean.wav',
#  'Unpopular/Rihanna - Man Down.wav',
#  'Unpopular/Maroon 5 - Never Gonna Leave This Bed (Official Music Video).wav',
#  'Unpopular/Marvins Room.wav',
#  'Unpopular/Avril Lavigne - Smile (Official Music Video).wav',
#  'Unpopular/Taylor Swift - The Story Of Us.wav',
#  "Unpopular/Rascal Flatts - I Won't Let Go (Official Video).wav",
#  'Unpopular/Nicki Minaj - Did It On Em (Explicit).wav',
#  'Unpopular/Chris Brown - No Bullshit (Official HD Video).wav',
#  'Unpopular/Nicki Minaj - Right Thru Me (Clean Version) (Official Music Video).wav',
#  "Unpopular/Carrie Underwood - Mama's Song (Official Video).wav",
#  'Unpopular/Why Wait - Rascal Flatts - Lyrics.wav',
#  'Unpopular/Coldplay - Christmas Lights (Official Video).wav',
#  'Unpopular/Daughtry - September (Official Music Video).wav',
#  'Unpopular/Angel.wav',
#  'Unpopular/Ne-Yo - One In A Million (Official Music Video).wav',
#  'Unpopular/Ne-Yo - Beautiful Monster (Official Music Video).wav',
#  'Unpopular/Nickelback - This Afternoon [OFFICIAL VIDEO].wav',
#  'Unpopular/Kanye West - POWER.wav',
#  'Unpopular/Glitter In the Air.wav',
#  'Unpopular/Ne-Yo - Champagne Life (Official Music Video).wav',
#  "Unpopular/Miley Cyrus - Can't Be Tamed (Official Video).wav",
#  'Unpopular/Justin Bieber - U Smile (Official Music Video).wav',
#  'Unpopular/Carrie Underwood - Temporary Home (Official Video).wav',
#  "Unpopular/T.I. - I'm Back [Official Video].wav",
#  'Unpopular/Miley Cyrus - When I Look At You (Lyrics) 🎵.wav',
#  'Unpopular/Mary J. Blige - I Am (Official Music Video).wav',
#  'Unpopular/Rascal Flatts - Unstoppable (Olympics Mix) - Team USA Soundtrack Official Video (HD).wav',
#  "Unpopular/Taylor Swift - Fearless (Taylor's Version) (Lyric Video).wav",
#  'Unpopular/Avril Lavigne - Alice (Official Music Video).wav',
#  'Unpopular/Taylor Swift - Fifteen.wav',
#  'Unpopular/Carrie Underwood - Cowboy Casanova (Official Video).wav',
#  'Unpopular/Rihanna - Russian Roulette (Official Music Video).wav',
#  'Unpopular/Empire State of Mind (Part II) Broken Down.wav',
#  'Unpopular/Justin Bieber - One Less Lonely Girl (Official Music Video).wav',
#  'Unpopular/Papers.wav',
#  'Unpopular/Nickelback - Never Gonna Be Alone [OFFICIAL VIDEO].wav',
#  'Unpopular/Elevator.wav',
#  'Unpopular/Chris Brown - Crawl (Official HD Video).wav',
#  'Unpopular/Lil Wayne - On Fire (Official Music Video).wav',
#  'Unpopular/P!nk - Funhouse (Official Video).wav',
#  'Unpopular/Down To Earth.wav',
#  "Unpopular/Alicia Keys - Doesn't Mean Anything (Official Video).wav",
#  'Unpopular/Bigger.wav',
#  'Unpopular/Rascal Flatts - Summer Nights (Official Video).wav',
#  'Unpopular/Beyoncé - Ego.wav',
#  'Unpopular/Sean Paul - So Fine (Official Video).wav',
#  "Unpopular/LMFAO - I'm In Miami Trick.wav",
#  "Unpopular/Daughtry - You Don't Belong (Official).wav",
#  'Unpopular/Eminem - Beautiful (Official Music Video).wav',
#  'Unpopular/Rascal Flatts - Here Comes Goodbye (Official Music Video).wav',
#  'Unpopular/Hot Revolver - Lil Wayne (Lyrics).wav',
#  'Unpopular/Katy Perry - Thinking Of You (Official).wav',
#  "Unpopular/Carrie Underwood 'Home Sweet Home' - OFFICIAL AUDIO.wav",
#  'Unpopular/Miley Cyrus - Hoedown Throwdown.wav',
#  "Unpopular/Taylor Swift - You're Not Sorry (Taylor's Version) (Lyric Video).wav",
#  'Unpopular/Rihanna - Rehab (Official Music Video) ft. Justin Timberlake.wav',
#  'Unpopular/Usher - Trading Places (Official Video).wav',
#  'Unpopular/Here by Rascal Flatts.wav',
#  'Unpopular/Carrie Underwood - Just A Dream (Official Video).wav',
#  'Unpopular/Leona Lewis - Run (Official Video).wav',
#  'Unpopular/Daughtry - What About Now (Official Music Video).wav',
#  "Unpopular/Nickelback - I'd Come For You.wav",
#  'Unpopular/Jonas Brothers - Lovebug (Official Music Video).wav',
#  "Unpopular/Pushin' Me Away.wav",
#  "Unpopular/Taylor Swift - Should've Said No (Lyrics).wav",
#  'Unpopular/Chris Brown - Take You Down (Audio).wav',
#  'Unpopular/Alicia Keys - Teenage Love Affair (Official Video).wav',
#  'Unpopular/Carrie Underwood - Last Name (Official Video).wav',
#  'Unpopular/Usher - Moving Mountains (Official Video).wav',
#  'Unpopular/Jonas Brothers - Play My Music.wav',
#  'Unpopular/Jonas Brothers - When You Look Me In The Eyes.wav',
#  'Unpopular/Carrie Underwood - All-American Girl (Official Video).wav',
#  'Unpopular/Taylor Swift - Picture To Burn.wav',
#  'Unpopular/Britney Spears - Break The Ice (Official HD Video).wav',
#  "Unpopular/Maroon 5 - Won't Go Home Without You (Official Music Video).wav",
#  'Unpopular/Rascal Flatts - Every Day (Official Video).wav',
#  'Unpopular/Ne-Yo - Go On Girl (Official Music Video).wav',
#  'Unpopular/Daughtry - Over You.wav',
#  'Unpopular/Maroon 5 - Wake Up Call (Official Music Video).wav',
#  'Unpopular/Chris Brown - This Christmas (Official HD Video).wav',
#  'Unpopular/Britney Spears - Gimme More (Official HD Video).wav',
#  'Unpopular/Carrie Underwood - So Small (Official Video).wav',
#  'Unpopular/Winner At A Losing Game.wav',
#  'Unpopular/Work That - Mary J Blige.wav',
#  'Unpopular/Jonas Brothers - S.O.S..wav',
#  'Unpopular/Carrie Underwood - Do You Hear What I Hear (Official Audio).wav',
#  'Unpopular/Rascal Flatts - Take Me There (Official Video).wav',
#  'Unpopular/Akon - Sorry, Blame It On Me (Official Music Video).wav',
#  'Unpopular/Ne-Yo - Do You (Official Music Video).wav',
#  "Unpopular/Avril Lavigne - When You're Gone (Official Video).wav",
#  'Unpopular/Gwen Stefani - 4 In The Morning (Closed Captioned).wav',
#  'Unpopular/Get Me Bodied (Extended Mix).wav',
#  "Unpopular/Kanye West - Can't Tell Me Nothing.wav",
#  'Unpopular/Carrie Underwood - Wasted (Official Video).wav',
#  'Unpopular/T.I Top Back.wav',
#  'Unpopular/Look After You - The Fray.wav',
#  'Unpopular/Rascal Flatts - Stand.wav',
#  'Unpopular/Jonas Brothers - Year 3000.wav',
#  'Unpopular/Rascal Flatts - My Wish.wav',
#  'Unpopular/Taylor Swift - Tim McGraw.wav',
#  'Unpopular/The Fray - Happy Xmas (War Is Over).wav',
#  'Unpopular/Mary J. Blige - Take Me As I Am (Official Music Video).wav',
#  'Unpopular/Beyoncé - Listen [Official First Video].wav',
#  'Unpopular/Beyoncé - Ring The Alarm (Video).wav',
#  'Unpopular/Me And My Gang.wav',
#  "Unpopular/Carrie Underwood - Don't Forget To Remember Me (Official Video).wav",
#  'Unpopular/Gwen Stefani - Crash.wav',
#  'Unpopular/Gwen Stefani - Luxurious (Remix Version, Closed Captioned) ft. Slim Thug.wav',
#  "Unpopular/Rihanna - If It's Lovin' That You Want (Official Music Video).wav",
#  'Unpopular/Lil Wayne - Fireman (Official Music Video).wav',
#  'Unpopular/Alicia Keys - Unbreakable (Official Video).wav',
#  'Unpopular/Rascal Flatts - Skin (Sarabeth) (Official Video).wav']

# %% [markdown]
# ### Method to extract chorus
#
# You have to download ffmpeg `<b>conda install -c conda-forge ffmpeg</b>` and use anconda.
#
# *`parametes:`*
# - `path:` path of full song.
# - `main:` main directory to save chorus.
# - `songname:` we take name of song from path.
# - `Newpath:` new path to save chorus in it.
#
#     return Newpath to save it in new dataframe

# %%
import warnings
warnings.filterwarnings('ignore')
from pychorus import find_and_output_chorus

def extract_chorus(path, main):
    songname = path.split('/', 2)[1].split('.')[0]
    Newpath = main + '/' + songname + '.wav'
    
    chorus = find_and_output_chorus(path, Newpath, 15)
    if chorus == None:
        return None
    
    else:
        return Newpath

# %% [markdown]
# ### Extract chorus
#
# *Parameters*
# - `i:` iterator for looping in every path in paths.
#
# extract method when i from 0 to 376 is popular(Songs/RepeatedPopularChorus) and from 377 to end of data is unpopular(Unpopular/RepeatedUnpopularChorus).
#
# `Note:`
#
# *It took more than 6 hours*

# %%
i = 0
while i < len(paths):
    if i <= 376:
        # Songs/RepeatedPopularChorus directory to collect all popular chours.
        path = extract_chorus(paths[i], 'Songs/RepeatedPopularChorus') 
        
    else:
        # Unpopular/RepeatedUnpopularChorus directory to collect all unpopular chours.
        path = extract_chorus(paths[i], 'Unpopular/RepeatedUnpopularChorus') 

    data.append({'title': titles[i], 'choruspath': path})
    i += 1
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\miniconda3\envs\mysongenv\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     152             # Otherwise, create the soundfile object
# --> 153             context = sf.SoundFile(path)
#     154
#
# ~\miniconda3\envs\mysongenv\lib\site-packages\soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# ~\miniconda3\envs\mysongenv\lib\site-packages\soundfile.py in _open(self, file, mode_int, closefd)
#    1182             raise TypeError("Invalid file: {0!r}".format(self.name))
# -> 1183         _error_check(_snd.sf_error(file_ptr),
#    1184                      "Error opening {0!r}: ".format(self.name))
#
# ~\miniconda3\envs\mysongenv\lib\site-packages\soundfile.py in _error_check(err, prefix)
#    1356         err_str = _snd.sf_error_number(err)
# -> 1357         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1358
#
# RuntimeError: Error opening 'Songs/The Weeknd - Blinding Lights (Official Video).wav': File contains data in an unknown format.
#
# During handling of the above exception, another exception occurred:
#
# NoBackendError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25112/998376810.py in <module>
#       3     if i <= 376:
#       4         # Songs/RepeatedPopularChorus directory to collect all popular chours.
# ----> 5         path = extract_chorus(paths[i], 'Songs/RepeatedPopularChorus')
#       6
#       7     else:
#
# ~\AppData\Local\Temp/ipykernel_25112/604662110.py in extract_chorus(path, main)
#       7     Newpath = main + '/' + songname + '.wav'
#       8
# ----> 9     chorus = find_and_output_chorus(path, Newpath, 15)
#      10     if chorus == None:
#      11         return None
#
# ~\miniconda3\envs\mysongenv\lib\site-packages\pychorus\helpers.py in find_and_output_chorus(input_file, output_file, clip_length)
#     174     Returns: Time in seconds of the start of the best chorus
#     175     """
# --> 176     chroma, song_wav_data, sr, song_length_sec = create_chroma(input_file)
#     177     chorus_start = find_chorus(chroma, sr, song_length_sec, clip_length)
#     178     if chorus_start is None:
#
# ~\miniconda3\envs\mysongenv\lib\site-packages\pychorus\helpers.py in create_chroma(input_file, n_fft)
#     116              and the song length in seconds
#     117     """
# --> 118     y, sr = librosa.load(input_file)
#     119     song_length_sec = y.shape[0] / float(sr)
#     120     S = np.abs(librosa.stft(y, n_fft=n_fft))**2
#
# ~\miniconda3\envs\mysongenv\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     170         if isinstance(path, (str, pathlib.PurePath)):
#     171             warnings.warn("PySoundFile failed. Trying audioread instead.", stacklevel=2)
# --> 172             y, sr_native = __audioread_load(path, offset, duration, dtype)
#     173         else:
#     174             raise (exc)
#
# ~\miniconda3\envs\mysongenv\lib\site-packages\librosa\core\audio.py in __audioread_load(path, offset, duration, dtype)
#     194
#     195     y = []
# --> 196     with audioread.audio_open(path) as input_file:
#     197         sr_native = input_file.samplerate
#     198         n_channels = input_file.channels
#
# ~\miniconda3\envs\mysongenv\lib\site-packages\audioread\__init__.py in audio_open(path, backends)
#     114
#     115     # All backends failed!
# --> 116     raise NoBackendError()
#
# NoBackendError:

# %% [markdown]
# ### Convert data to dataframe and save it as csv file

# %%
# At first time we should convert data.
# newData = pd.DataFrame(data)  

# Because I do it in several times, I use this code but I must use code above in the first time.
newData = pd.read_csv('Data/NewData.csv')
for row in data:
    newData = newData.append(row, ignore_index = True)

# %% [markdown]
# ### Check if doubled choruspath in two songs.

# %%
paths = list(newData['choruspath'])
lost = []
for path in paths:
    if len(newData[newData['choruspath']==path]) > 1:
        lost.append(path)

lost

# %% [markdown]
# ### Clean data if some songs don't have chours or in lost list

# %%
newData = newData[newData.choruspath.isin(lost) == False]
newData.dropna(inplace=True)

# %%
## I did it because I made code in several days to save my work.
newData.reset_index()
newData.to_csv('Data/newData.csv', index=False)

# %% [markdown]
# ### Now add newData to dataset and clean it.

# %%
dataset['choruspath'] = newData['choruspath'] # Add path column
dataset['title'] = newData['title'] # Add title column with Title column in newData to check data
newtitles = list(dataset['title'])  # to collect titles which we added
titles = list(dataset['Title'])     # to coolect old Titles

# %%
lostdata = []  # list to Titles and titles with doesn't matches
for i in range(len(titles)):
    if titles[i] != newtitles[i]:
        lostdata.append(titles[i])

# to see if any lost data or not. if(just delete rows) else dataset is good
lostdata

# %%
# delete nan rows and data which titles doesn't match
dataset = dataset[dataset.Title.isin(lostdata) == False]
dataset.dropna(inplace=True)

# %%
# if we deleted rows just reset index after that delete title row
dataset.reset_index()
del dataset['title']

# %%
# Save last data
dataset.to_csv('Data\chorusData.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv('Data\chorusData.csv')
print(df.shape)
df.head()
# Out:
# (751, 5)
#            Artist                           Title  Label  \
# 0      The Weeknd                 Blinding Lights      1
# 1  Olivia Rodrigo                        Good 4 U      1
# 2  Olivia Rodrigo                 Drivers License      1
# 3       Lil Nas X  Montero (Call Me By Your Name)      1
# 4             BTS                          Butter      1
#
#                                                 Path  \
# 0  Songs/The Weeknd - Blinding Lights (Official V...
# 1  Songs/Olivia Rodrigo - good 4 u (Official Vide...
# 2  Songs/Olivia Rodrigo - drivers license (Offici...
# 3  Songs/Lil Nas X - MONTERO (Call Me By Your Nam...
# 4         Songs/BTS (방탄소년단) 'Butter' Official MV.mp3
#
#                                           choruspath
# 0  Songs/RepeatedPopularChorus/The Weeknd - Blind...
# 1  Songs/RepeatedPopularChorus/Olivia Rodrigo - g...
# 2  Songs/RepeatedPopularChorus/Olivia Rodrigo - d...
# 3  Songs/RepeatedPopularChorus/Lil Nas X - MONTER...
# 4  Songs/RepeatedPopularChorus/BTS (방탄소년단) 'Butte...
